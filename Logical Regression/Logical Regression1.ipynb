# %%
from pyspark.sql import SparkSession

# %%
spark = SparkSession.builder.appName('logical Regression1').getOrCreate()

# %%
from pyspark.ml.classification import LogisticRegression

# %%
data = spark.read.format('libsvm').load('sample_libsvm_data.txt')

# %%
data.show()
# Out:
# +-----+--------------------+
# |label|            features|
# +-----+--------------------+
# |  0.0|(692,[127,128,129...|
# |  1.0|(692,[158,159,160...|
# |  1.0|(692,[124,125,126...|
# |  1.0|(692,[152,153,154...|
# |  1.0|(692,[151,152,153...|
# |  0.0|(692,[129,130,131...|
# |  1.0|(692,[158,159,160...|
# |  1.0|(692,[99,100,101,...|
# |  0.0|(692,[154,155,156...|
# |  0.0|(692,[127,128,129...|
# |  1.0|(692,[154,155,156...|
# |  0.0|(692,[153,154,155...|
# |  0.0|(692,[151,152,153...|
# |  1.0|(692,[129,130,131...|
# |  0.0|(692,[154,155,156...|
# |  1.0|(692,[150,151,152...|
# |  0.0|(692,[124,125,126...|
# |  0.0|(692,[152,153,154...|
# |  1.0|(692,[97,98,99,12...|
# |  1.0|(692,[124,125,126...|
# +-----+--------------------+
# only showing top 20 rows

# %%
regmodel = LogisticRegression(labelCol='label',featuresCol='features')

# %%
fitmodel = regmodel.fit(data)

# %%
summary = fitmodel.summary

# %%
summary.predictions.show()
# Out:
# +-----+--------------------+--------------------+--------------------+----------+
# |label|            features|       rawPrediction|         probability|prediction|
# +-----+--------------------+--------------------+--------------------+----------+
# |  0.0|(692,[127,128,129...|[19.8534775947478...|[0.99999999761359...|       0.0|
# |  1.0|(692,[158,159,160...|[-20.377398194908...|[1.41321555111056...|       1.0|
# |  1.0|(692,[124,125,126...|[-27.401459284891...|[1.25804865126979...|       1.0|
# |  1.0|(692,[152,153,154...|[-18.862741612668...|[6.42710509170303...|       1.0|
# |  1.0|(692,[151,152,153...|[-20.483011833009...|[1.27157209200604...|       1.0|
# |  0.0|(692,[129,130,131...|[19.8506078990277...|[0.99999999760673...|       0.0|
# |  1.0|(692,[158,159,160...|[-20.337256674833...|[1.47109814695581...|       1.0|
# |  1.0|(692,[99,100,101,...|[-19.595579753418...|[3.08850168102631...|       1.0|
# ...

# %%
train,test = data.randomSplit([0.7,0.3])

# %%
modeltrain = LogisticRegression()

# %%
fitmodeltrain = modeltrain.fit(train)

# %%
predicitionlabels = fitmodeltrain.evaluate(test)

# %%
predicitionlabels.predictions.show()
# Out:
# +-----+--------------------+--------------------+--------------------+----------+
# |label|            features|       rawPrediction|         probability|prediction|
# +-----+--------------------+--------------------+--------------------+----------+
# |  0.0|(692,[98,99,100,1...|[25.2855515182999...|[0.99999999998956...|       0.0|
# |  0.0|(692,[100,101,102...|[8.65199347260334...|[0.99982525245671...|       0.0|
# |  0.0|(692,[122,123,124...|[20.9047386174774...|[0.99999999916595...|       0.0|
# |  0.0|(692,[122,123,148...|[22.2633238128843...|[0.99999999978563...|       0.0|
# |  0.0|(692,[123,124,125...|[30.3614135638092...|[0.99999999999993...|       0.0|
# |  0.0|(692,[123,124,125...|[20.3738293733146...|[0.99999999858173...|       0.0|
# |  0.0|(692,[124,125,126...|[18.2589680224824...|[0.99999998824477...|       0.0|
# |  0.0|(692,[124,125,126...|[22.4873538141425...|[0.99999999982865...|       0.0|
# ...

# %%
from pyspark.ml.evaluation import BinaryClassificationEvaluator,MulticlassClassificationEvaluator

# %%
myeval = BinaryClassificationEvaluator()

# %%
rocresults = myeval.evaluate(predicitionlabels.predictions)

# %%
rocresults
# Out:
# 1.0
